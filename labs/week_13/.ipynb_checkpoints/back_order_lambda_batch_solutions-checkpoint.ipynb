# %% [markdown]
# # Back Order Lambda Batch Solutions

# %%
import kafka

import pprint

from IPython.display import clear_output

import time

# %% [markdown]
# ## You try it -
#
#
# ## Modify back_order_process to publish to the back_order_pub_sub topic;  create a new jupyter notebook back_order_lambda_batch to subscribe to back_order_pub_sub in batch mode; solutions can be found in back_order_process_solutions and back_order_lambda_batch_solutions

# %%
topic = "back_order_pub_sub"

subscriber_read_all = kafka.KafkaConsumer(topic, 
                                          bootstrap_servers=['kafka:29092'], 
                                          auto_offset_reset='earliest')

# %%
if subscriber_read_all.assignment():

    subscriber_read_all.seek_to_beginning()

message_list = []

while (True):
    
    poll_result = subscriber_read_all.poll(timeout_ms=500)
    
    if poll_result == {}:
        break

    items = poll_result.items()

    for (topic, messages) in items:
    
        for message in messages:
            
            message_list.append([message.offset, message.value])
            
i = 0

for message in message_list:
    
    if (i < 5) or (i > len(message_list) - 6):
        print("Offset:", message[0], "   Value:", message[1][:75])
   
    if i == 5:
        print("\n... only showing a max of first 5 and max of last 5 ... \n")
        
    i += 1
# Out:
# Offset: 0    Value: b'{"order_id": 14375, "sub_total": 29.95, "tax": 2.4, "total": 32.35, "line_i'
# Offset: 1    Value: b'{"order_id": 14376, "sub_total": 299.5, "tax": 23.96, "total": 323.46, "lin'
# Offset: 2    Value: b'{"order_id": 14377, "sub_total": 89.85, "tax": 7.19, "total": 97.04, "line_'
# Offset: 3    Value: b'{"order_id": 14378, "sub_total": 239.6, "tax": 19.17, "total": 258.77, "lin'
# Offset: 4    Value: b'{"order_id": 14379, "sub_total": 29.95, "tax": 2.4, "total": 32.35, "line_i'
#
# ... only showing a max of first 5 and max of last 5 ...
#
# Offset: 59    Value: b'{"order_id": 14461, "sub_total": 59.9, "tax": 4.79, "total": 64.69, "line_i'
# Offset: 60    Value: b'{"order_id": 14463, "sub_total": 29.95, "tax": 2.4, "total": 32.35, "line_i'
# Offset: 61    Value: b'{"order_id": 14464, "sub_total": 59.9, "tax": 4.79, "total": 64.69, "line_i'
# Offset: 62    Value: b'{"order_id": 14465, "sub_total": 239.6, "tax": 19.17, "total": 258.77, "lin'
# Offset: 63    Value: b'{"order_id": 14466, "sub_total": 119.8, "tax": 9.58, "total": 129.38, "line'

# %%
topic = "back_order_pub_sub"

subscriber_batch = kafka.KafkaConsumer(topic, 
                                       bootstrap_servers=['kafka:29092'], 
                                       auto_offset_reset='earliest')

# %%
batch_time_interval = 5.0

if subscriber_batch.assignment():

    subscriber_batch.seek_to_beginning()

batch_number = 1

message_list = []

while (True):
    
    poll_result = subscriber_batch.poll(timeout_ms=500)
    
    if poll_result == {}:
        
        if len(message_list) > 0:
            
            clear_output(wait=True)
            
            print("\n======================================")
            print("   Back Order Lambda Batch Process")
            print("=======================================\n")
            print("\n------------------------")
            print("   Batch ", batch_number)
            print("------------------------\n\n")
            
            for message in message_list:
                
                print("Offset:", message[0], "   Value:", message[1][:75])
                
            message_list = []
            
            batch_number += 1
            
        time.sleep(batch_time_interval)
              
    else:

        items = poll_result.items()

        for (topic, messages) in items:
    
            for message in messages:
        
                message_list.append([message.offset, message.value])
# Out:
# ======================================
#    Back Order Lambda Batch Process
# =======================================
#
#
# ------------------------
#    Batch  1
# ------------------------
#
#
# Offset: 0    Value: b'{"order_id": 14375, "sub_total": 29.95, "tax": 2.4, "total": 32.35, "line_i'
# Offset: 1    Value: b'{"order_id": 14376, "sub_total": 299.5, "tax": 23.96, "total": 323.46, "lin'
# Offset: 2    Value: b'{"order_id": 14377, "sub_total": 89.85, "tax": 7.19, "total": 97.04, "line_'
# Offset: 3    Value: b'{"order_id": 14378, "sub_total": 239.6, "tax": 19.17, "total": 258.77, "lin'
# Offset: 4    Value: b'{"order_id": 14379, "sub_total": 29.95, "tax": 2.4, "total": 32.35, "line_i'
# Offset: 5    Value: b'{"order_id": 14380, "sub_total": 59.9, "tax": 4.79, "total": 64.69, "line_i'
# Offset: 6    Value: b'{"order_id": 14383, "sub_total": 329.45, "tax": 26.36, "total": 355.81, "li'
# Offset: 7    Value: b'{"order_id": 14384, "sub_total": 119.8, "tax": 9.58, "total": 129.38, "line'
# Offset: 8    Value: b'{"order_id": 14385, "sub_total": 359.4, "tax": 28.75, "total": 388.15, "lin'
# Offset: 9    Value: b'{"order_id": 14386, "sub_total": 329.45, "tax": 26.36, "total": 355.81, "li'
# Offset: 10    Value: b'{"order_id": 14387, "sub_total": 59.9, "tax": 4.79, "total": 64.69, "line_i'
# Offset: 11    Value: b'{"order_id": 14391, "sub_total": 149.75, "tax": 11.98, "total": 161.73, "li'
# Offset: 12    Value: b'{"order_id": 14392, "sub_total": 269.55, "tax": 21.56, "total": 291.11, "li'
# Offset: 13    Value: b'{"order_id": 14393, "sub_total": 269.55, "tax": 21.56, "total": 291.11, "li'
# Offset: 14    Value: b'{"order_id": 14394, "sub_total": 239.6, "tax": 19.17, "total": 258.77, "lin'
# Offset: 15    Value: b'{"order_id": 14395, "sub_total": 29.95, "tax": 2.4, "total": 32.35, "line_i'
# Offset: 16    Value: b'{"order_id": 14396, "sub_total": 239.6, "tax": 19.17, "total": 258.77, "lin'
# Offset: 17    Value: b'{"order_id": 14397, "sub_total": 149.75, "tax": 11.98, "total": 161.73, "li'
# Offset: 18    Value: b'{"order_id": 14398, "sub_total": 209.65, "tax": 16.77, "total": 226.42, "li'
# Offset: 19    Value: b'{"order_id": 14399, "sub_total": 59.9, "tax": 4.79, "total": 64.69, "line_i'
# Offset: 20    Value: b'{"order_id": 14402, "sub_total": 359.4, "tax": 28.75, "total": 388.15, "lin'
# Offset: 21    Value: b'{"order_id": 14405, "sub_total": 29.95, "tax": 2.4, "total": 32.35, "line_i'
# Offset: 22    Value: b'{"order_id": 14406, "sub_total": 89.85, "tax": 7.19, "total": 97.04, "line_'
# Offset: 23    Value: b'{"order_id": 14407, "sub_total": 239.6, "tax": 19.17, "total": 258.77, "lin'
# Offset: 24    Value: b'{"order_id": 14408, "sub_total": 29.95, "tax": 2.4, "total": 32.35, "line_i'
# Offset: 25    Value: b'{"order_id": 14411, "sub_total": 149.75, "tax": 11.98, "total": 161.73, "li'
# Offset: 26    Value: b'{"order_id": 14412, "sub_total": 59.9, "tax": 4.79, "total": 64.69, "line_i'
# Offset: 27    Value: b'{"order_id": 14413, "sub_total": 239.6, "tax": 19.17, "total": 258.77, "lin'
# Offset: 28    Value: b'{"order_id": 14415, "sub_total": 269.55, "tax": 21.56, "total": 291.11, "li'
# Offset: 29    Value: b'{"order_id": 14417, "sub_total": 269.55, "tax": 21.56, "total": 291.11, "li'
# Offset: 30    Value: b'{"order_id": 14418, "sub_total": 269.55, "tax": 21.56, "total": 291.11, "li'
# Offset: 31    Value: b'{"order_id": 14419, "sub_total": 179.7, "tax": 14.38, "total": 194.08, "lin'
# Offset: 32    Value: b'{"order_id": 14420, "sub_total": 359.4, "tax": 28.75, "total": 388.15, "lin'
# Offset: 33    Value: b'{"order_id": 14421, "sub_total": 329.45, "tax": 26.36, "total": 355.81, "li'
# Offset: 34    Value: b'{"order_id": 14423, "sub_total": 269.55, "tax": 21.56, "total": 291.11, "li'
# Offset: 35    Value: b'{"order_id": 14426, "sub_total": 119.8, "tax": 9.58, "total": 129.38, "line'
# Offset: 36    Value: b'{"order_id": 14429, "sub_total": 149.75, "tax": 11.98, "total": 161.73, "li'
# Offset: 37    Value: b'{"order_id": 14430, "sub_total": 29.95, "tax": 2.4, "total": 32.35, "line_i'
# Offset: 38    Value: b'{"order_id": 14432, "sub_total": 59.9, "tax": 4.79, "total": 64.69, "line_i'
# Offset: 39    Value: b'{"order_id": 14436, "sub_total": 269.55, "tax": 21.56, "total": 291.11, "li'
# Offset: 40    Value: b'{"order_id": 14437, "sub_total": 329.45, "tax": 26.36, "total": 355.81, "li'
# Offset: 41    Value: b'{"order_id": 14438, "sub_total": 329.45, "tax": 26.36, "total": 355.81, "li'
# Offset: 42    Value: b'{"order_id": 14439, "sub_total": 29.95, "tax": 2.4, "total": 32.35, "line_i'
# Offset: 43    Value: b'{"order_id": 14440, "sub_total": 119.8, "tax": 9.58, "total": 129.38, "line'
# Offset: 44    Value: b'{"order_id": 14442, "sub_total": 209.65, "tax": 16.77, "total": 226.42, "li'
# Offset: 45    Value: b'{"order_id": 14443, "sub_total": 329.45, "tax": 26.36, "total": 355.81, "li'
# Offset: 46    Value: b'{"order_id": 14444, "sub_total": 89.85, "tax": 7.19, "total": 97.04, "line_'
# Offset: 47    Value: b'{"order_id": 14445, "sub_total": 179.7, "tax": 14.38, "total": 194.08, "lin'
# Offset: 48    Value: b'{"order_id": 14447, "sub_total": 209.65, "tax": 16.77, "total": 226.42, "li'
# Offset: 49    Value: b'{"order_id": 14448, "sub_total": 269.55, "tax": 21.56, "total": 291.11, "li'
# Offset: 50    Value: b'{"order_id": 14450, "sub_total": 149.75, "tax": 11.98, "total": 161.73, "li'
# Offset: 51    Value: b'{"order_id": 14451, "sub_total": 359.4, "tax": 28.75, "total": 388.15, "lin'
# Offset: 52    Value: b'{"order_id": 14452, "sub_total": 179.7, "tax": 14.38, "total": 194.08, "lin'
# Offset: 53    Value: b'{"order_id": 14453, "sub_total": 359.4, "tax": 28.75, "total": 388.15, "lin'
# Offset: 54    Value: b'{"order_id": 14455, "sub_total": 179.7, "tax": 14.38, "total": 194.08, "lin'
# Offset: 55    Value: b'{"order_id": 14456, "sub_total": 149.75, "tax": 11.98, "total": 161.73, "li'
# Offset: 56    Value: b'{"order_id": 14457, "sub_total": 89.85, "tax": 7.19, "total": 97.04, "line_'
# Offset: 57    Value: b'{"order_id": 14459, "sub_total": 359.4, "tax": 28.75, "total": 388.15, "lin'
# Offset: 58    Value: b'{"order_id": 14460, "sub_total": 179.7, "tax": 14.38, "total": 194.08, "lin'
# Offset: 59    Value: b'{"order_id": 14461, "sub_total": 59.9, "tax": 4.79, "total": 64.69, "line_i'
# Offset: 60    Value: b'{"order_id": 14463, "sub_total": 29.95, "tax": 2.4, "total": 32.35, "line_i'
# Offset: 61    Value: b'{"order_id": 14464, "sub_total": 59.9, "tax": 4.79, "total": 64.69, "line_i'
# Offset: 62    Value: b'{"order_id": 14465, "sub_total": 239.6, "tax": 19.17, "total": 258.77, "lin'
# Offset: 63    Value: b'{"order_id": 14466, "sub_total": 119.8, "tax": 9.58, "total": 129.38, "line'
# Offset: 64    Value: b'{"order_id": 14467, "sub_total": 359.4, "tax": 28.75, "total": 388.15, "lin'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_672/3790751167.py in <module>
#      34             batch_number += 1
#      35
# ---> 36         time.sleep(batch_time_interval)
#      37
#      38     else:
#
# KeyboardInterrupt:
