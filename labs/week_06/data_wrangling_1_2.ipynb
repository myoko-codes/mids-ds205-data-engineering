# %% [markdown]
# # Data Wrangling 1.2

# %%
import csv

import math
import numpy as np
import pandas as pd

import psycopg2

# %%
#
# function to run a select query and return rows in a pandas dataframe
# pandas puts all numeric values from postgres to float
# if it will fit in an integer, change it to integer
#

def my_select_query_pandas(query, rollback_before_flag, rollback_after_flag):
    "function to run a select query and return rows in a pandas dataframe"
    
    if rollback_before_flag:
        connection.rollback()
    
    df = pd.read_sql_query(query, connection)
    
    if rollback_after_flag:
        connection.rollback()
    
    # fix the float columns that really should be integers
    
    for column in df:
    
        if df[column].dtype == "float64":

            fraction_flag = False

            for value in df[column].values:
                
                if not np.isnan(value):
                    if value - math.floor(value) != 0:
                        fraction_flag = True

            if not fraction_flag:
                df[column] = df[column].astype('Int64')
    
    return(df)

# %%
connection = psycopg2.connect(
    user = "postgres",
    password = "ucb",
    host = "postgres",
    port = "5432",
    database = "postgres"
)

# %%
cursor = connection.cursor()

# %% [markdown]
# # Lab: Reading CSV Files

# %%
def my_read_csv_file(file_name, limit):
    "read the csv file and print only the first limit rows"
    
    csv_file = open(file_name, "r")
    
    csv_data = csv.reader(csv_file)
    
    i = 0
    
    for row in csv_data:
        i += 1
        if i <= limit:
            print(row)
            
    print("\nPrinted ", min(limit, i), "lines of ", i, "total lines.")

# %%
my_read_csv_file("temp_stores.csv", limit=10)
# Out:
# ['store_id', 'street', 'city', 'state', 'zip', 'latitude', 'longitude']
# ['1', '3000 Telegraph Ave', 'Berkeley', 'CA', '94705', '37.8555', '-122.2604']
# ['2', '1001 Broadway', 'Seattle', 'WA', '98122', '47.6114', '-122.3214']
# ['3', '2510 McKinney Ave', 'Dallas', 'TX', '75201', '32.7958', '-96.8015']
# ['4', '299 SE 3rd Ave', 'Miami', 'FL', '33131', '25.7720', '-80.1891']
# ['5', '1202 Broadway', 'Nashville', 'TN', '37203', '36.1568', '-86.7881']
#
# Printed  6 lines of  6 total lines.

# %%
my_read_csv_file("temp_sales.csv", limit=10)
# Out:
# ['store_id', 'sale_id', 'customer_id', 'sale_date', 'total_amount']
# ['1', '128112', '3491', '2020-04-30', '24']
# ['1', '144249', '1597', '2020-05-16', '84']
# ['1', '163141', '4159', '2020-06-04', '96']
# ['1', '169216', '4198', '2020-06-09', '144']
# ['1', '179181', '5394', '2020-06-18', '48']
# ['1', '181897', '1958', '2020-06-20', '48']
# ['1', '248269', '4260', '2020-08-22', '60']
# ['1', '250031', '6782', '2020-08-23', '24']
# ['1', '255285', '563', '2020-08-29', '36']
#
# Printed  10 lines of  51 total lines.

# %%
my_read_csv_file("temp_random_sales.csv", limit=100)
# Out:
# ['store_id', 'sale_id']
# ['1', '128112']
# ['1', '144249']
# ['1', '163141']
# ['1', '169216']
# ['1', '179181']
# ['1', '181897']
# ['1', '248269']
# ['1', '250031']
# ['1', '255285']
# ['1', '263524']
# ['2', '105004']
# ['2', '109083']
# ['2', '115446']
# ['2', '115912']
# ['2', '119996']
# ['2', '144107']
# ['2', '158290']
# ['2', '203726']
# ['2', '217889']
# ['2', '218323']
# ['3', '99402']
# ['3', '131547']
# ['3', '131827']
# ['3', '134868']
# ['3', '154102']
# ['3', '164376']
# ['3', '177427']
# ['3', '183488']
# ['3', '186881']
# ['3', '209184']
# ['4', '89887']
# ['4', '111979']
# ['4', '115633']
# ['4', '137286']
# ['4', '138546']
# ['4', '143587']
# ['4', '177033']
# ['4', '177233']
# ['4', '183530']
# ['4', '192337']
# ['5', '88989']
# ['5', '104373']
# ['5', '105691']
# ['5', '107715']
# ['5', '109305']
# ['5', '126722']
# ['5', '136553']
# ['5', '136735']
# ['5', '147541']
# ['5', '157919']
#
# Printed  51 lines of  51 total lines.

# %% [markdown]
# ## You try it - read and print out some lines from the following csv files: temp_line_items.csv, temp_customers.csv, temp_products, temp_holidays

# %%
my_read_csv_file("temp_line_items.csv", limit=10)
# Out:
# ['store_id', 'sale_id', 'line_item_id', 'product_id', 'quantity']
# ['1', '128112', '1', '1', '1']
# ['1', '128112', '2', '8', '1']
# ['1', '144249', '1', '1', '1']
# ['1', '144249', '2', '2', '1']
# ['1', '144249', '3', '4', '2']
# ['1', '144249', '4', '6', '1']
# ['1', '144249', '5', '8', '2']
# ['1', '163141', '1', '1', '3']
# ['1', '163141', '2', '3', '1']
#
# Printed  10 lines of  177 total lines.

# %%
my_read_csv_file("temp_customers.csv", limit=10)
# Out:
# ['customer_id', 'first_name', 'last_name', 'street', 'city', 'state', 'zip', 'closest_store_id', 'distance']
# ['563', 'Rose', 'Slimings', '38 Iowa Street', 'Berkeley', 'CA', '94704', '1', '1']
# ['1597', 'Norry', 'Macauley', '654 Sommers Plaza', 'Oakland', 'CA', '94612', '1', '3']
# ['1958', 'Theresina', 'Penswick', '5975 Twin Pines Hill', 'Berkeley', 'CA', '94707', '1', '3']
# ['1991', 'Kevon', 'Wickett', '472 Arizona Court', 'Berkeley', 'CA', '94707', '1', '3']
# ['3491', 'Siouxie', "M'Quharge", '747 Westridge Center', 'Alameda', 'CA', '94501', '1', '6']
# ['4159', 'Cheryl', 'Broe', '7 Ruskin Alley', 'El Sobrante', 'CA', '94803', '1', '7']
# ['4198', 'Andreana', 'Drew', '11039 Cordelia Alley', 'El Sobrante', 'CA', '94803', '1', '7']
# ['4260', 'Dom', 'Risbrough', '3 Northland Crossing', 'Richmond', 'CA', '94805', '1', '7']
# ['5394', 'Katharina', 'Bavester', '522 Cordelia Lane', 'San Francisco', 'CA', '94102', '1', '10']
#
# Printed  10 lines of  51 total lines.

# %%
my_read_csv_file("temp_products.csv", limit=10)
# Out:
# ['product_id', 'description']
# ['1', 'Pistachio Salmon']
# ['2', 'Teriyaki Chicken']
# ['3', 'Spinach Orzo']
# ['4', 'Eggplant Lasagna']
# ['5', 'Chicken Salad']
# ['6', 'Curry Chicken']
# ['7', 'Tilapia Piccata']
# ['8', 'Brocolli Stir Fry']
#
# Printed  9 lines of  9 total lines.

# %%
my_read_csv_file("temp_holidays.csv", limit=10)
# Out:
# ['holiday_date', 'description', 'closed_flag']
# ['2020-01-01', "New Year's Day", 'f']
# ['2020-01-20', 'MLK Day', 'f']
# ['2020-02-17', "President's Day", 'f']
# ['2020-04-12', 'Easter', 'f']
# ['2020-05-10', "Mother's Day", 'f']
# ['2020-05-25', 'Memorial Day', 'f']
# ['2020-06-21', "Father's Day", 'f']
# ['2020-07-04', 'Independence Day', 'f']
# ['2020-09-07', 'Labor Day', 'f']
#
# Printed  10 lines of  13 total lines.

# %% [markdown]
# # Lab: Loading CSV Data into Database Tables

# %%
#
# drop all the temp tables in the foreign key order
#

connection.rollback()

query = """

drop table if exists temp_line_items;
drop table if exists temp_sales;
drop table if exists temp_products;
drop table if exists temp_customers;
drop table if exists temp_stores;
drop table if exists temp_holidays;
drop table if exists temp_random_sales;


"""

cursor.execute(query)

connection.commit()

# %%
#
# create all the temp tables in the foreign key order
#

connection.rollback()

query = """

create table temp_holidays (
  holiday_date date,
  description varchar(32),
  closed_flag boolean,
  primary key (holiday_date)
);

create table temp_products (
  product_id numeric(3),
  description varchar(32),
  primary key (product_id)
);

create table temp_stores (
  store_id numeric(6),
  street varchar(32),
  city varchar(32),
  state varchar(2),
  zip varchar(5),
  latitude numeric(7,4),
  longitude numeric(7,4),
  primary key (store_id)
);

create table temp_customers (
  customer_id numeric(6),
  first_name varchar(32),
  last_name varchar(32),
  street varchar(32),
  city varchar(32),
  state varchar(2),
  zip varchar(5),
  closest_store_id numeric(6),
  distance numeric(3),
  primary key (customer_id),
  foreign key (closest_store_id) references temp_stores(store_id)
);

create table temp_sales (
  store_id numeric(6),
  sale_id numeric(8),
  customer_id numeric(6),
  sale_date date,
  total_amount numeric(5),
  primary key (store_id, sale_id),
  foreign key (customer_id) references temp_customers (customer_id)
);

create table temp_line_items (
  store_id numeric(6),
  sale_id numeric(8),
  line_item_id numeric(3),
  product_id numeric(3),
  quantity numeric(3),
  primary key (store_id, sale_id, line_item_id),
  foreign key (product_id) references temp_products (product_id)
);

create table temp_random_sales (
  store_id numeric(6),
  sale_id numeric(8)
)

"""

cursor.execute(query)

connection.commit()

# %%
#
# load the csv files into the database tables in foreign key order
#

connection.rollback()

query = """

copy temp_stores
from '/user/labs/week_06/temp_stores.csv' delimiter ',' NULL '' csv header;

copy temp_customers
from '/user/labs/week_06/temp_customers.csv' delimiter ',' NULL '' csv header;

copy temp_sales
from '/user/labs/week_06/temp_sales.csv' delimiter ',' NULL '' csv header;

copy temp_random_sales
from '/user/labs/week_06/temp_random_sales.csv' delimiter ',' NULL '' csv header;


"""

cursor.execute(query)

connection.commit()

# %%
rollback_before_flag = True
rollback_after_flag = True

query = """

select * 
from temp_stores;

"""

my_select_query_pandas(query, rollback_before_flag, rollback_after_flag)
# Out:
#    store_id              street       city state    zip  latitude  longitude
# 0         1  3000 Telegraph Ave   Berkeley    CA  94705   37.8555  -122.2604
# 1         2       1001 Broadway    Seattle    WA  98122   47.6114  -122.3214
# 2         3   2510 McKinney Ave     Dallas    TX  75201   32.7958   -96.8015
# 3         4      299 SE 3rd Ave      Miami    FL  33131   25.7720   -80.1891
# 4         5       1202 Broadway  Nashville    TN  37203   36.1568   -86.7881

# %%
rollback_before_flag = True
rollback_after_flag = True

query = """

select * 
from temp_customers;

"""

my_select_query_pandas(query, rollback_before_flag, rollback_after_flag)
# Out:
#     customer_id first_name    last_name                    street  \
# 0           563       Rose     Slimings            38 Iowa Street
# 1          1597      Norry     Macauley         654 Sommers Plaza
# 2          1958  Theresina     Penswick      5975 Twin Pines Hill
# 3          1991      Kevon      Wickett         472 Arizona Court
# 4          3491    Siouxie    M'Quharge      747 Westridge Center
# 5          4159     Cheryl         Broe            7 Ruskin Alley
# 6          4198   Andreana         Drew      11039 Cordelia Alley
# 7          4260        Dom    Risbrough      3 Northland Crossing
# 8          5394  Katharina     Bavester         522 Cordelia Lane
# 9          6782    Lyndsay       Iuorio          4 Thackeray Road
# 10         9046       Beth    Scotchmor        6070 Merchant Park
# 11         9189    Cornell      Brammar  94261 Sunnyside Junction
# 12         9298    Cecilla        Lewry           987 Kim Terrace
# 13         9528     Markos       Toderi          6434 Mallard Way
# 14        10295      Debby        Leber       1660 Bluejay Circle
# 15        11291       Dasi       Radden          18 Hoepker Court
# 16        11779    Emlynne        Takle            1 Johnson Park
# 17        12160        Sim        Dorie         6709 Bayside Hill
# 18        12493       Lula     Stoneman          2 Gateway Center
# 19        14460    Shannon      Morrall   12076 Lotheville Circle
# 20        15481     Raquel       Ansill          57 Fordem Circle
# 21        15710        Ted      Campany           91111 West Road
# 22        15799  Zackariah     McCreath     64828 Farwell Terrace
# 23        16476     Yancey      Lamyman       3078 Emmet Junction
# 24        16932      Betta     Swatland        7060 Merchant Pass
# 25        17003      Pryce     Slafford     172 Bunker Hill Drive
# 26        17711  Sheffield    Dunkerton         11 Quincy Parkway
# 27        19226   Christin        Penny            3452 Muir Hill
# 28        19494    Brianne   Dundendale          7 Mcbride Center
# 29        19954     Merell  Cruikshanks          5 Armistice Road
# 30        22673        Sue     Delepine            117 Hauk Trail
# 31        23017       Darb      Goucher      654 Glendale Parkway
# 32        23319     Brnaba  Challicombe          22008 Jay Circle
# 33        23347      Royce     Fielders         8 Hermina Parkway
# 34        23902      Joice      Chidgey       7996 Loeprich Alley
# 35        24014    Michale       Caudle    322 Washington Parkway
# 36        25267      Tobin         Pude        70078 Porter Court
# 37        25339    Lucilia         Logg       62940 Towne Terrace
# 38        26882      Billy      Cattini  6858 Burning Wood Avenue
# 39        27380   Juliette   Simoncello      485 Hazelcrest Alley
# 40        27654     Nestor      Winfred     593 American Ash Hill
# 41        27728        Gus   Haliburton       11 Sommers Crossing
# 42        27926     Kerrin       Bridel          4582 Roth Street
# 43        27997     Meagan       Gussin         73526 2nd Terrace
# 44        28267  Frederica       Cabrer         99 Rutledge Trail
# 45        28750      Jareb         Girt      316 Saint Paul Point
# 46        29285  Ezmeralda    McCreadie        30 Gulseth Terrace
# 47        29783      Nobie      Nuemann        955 Beilfuss Place
# 48        29922     Garwin   Aleksankin          7 Delaware Place
# 49        30184      Mindy        Bockh          50432 Sachs Road
#
#                city state    zip  closest_store_id  distance
# 0          Berkeley    CA  94704                 1         1
# 1           Oakland    CA  94612                 1         3
# 2          Berkeley    CA  94707                 1         3
# 3          Berkeley    CA  94707                 1         3
# 4           Alameda    CA  94501                 1         6
# 5       El Sobrante    CA  94803                 1         7
# 6       El Sobrante    CA  94803                 1         7
# 7          Richmond    CA  94805                 1         7
# 8     San Francisco    CA  94102                 1        10
# 9      Walnut Creek    CA  94596                 1        12
# 10          Seattle    WA  98112                 2         2
# 11          Seattle    WA  98112                 2         2
# 12          Seattle    WA  98144                 2         2
# 13          Seattle    WA  98119                 2         3
# 14    Mercer Island    WA  98040                 2         5
# 15          Seattle    WA  98136                 2         6
# 16          Seattle    WA  98125                 2         7
# 17          Seattle    WA  98146                 2         8
# 18         Kirkland    WA  98034                 2         9
# 19     Port Orchard    WA  98366                 2        13
# 20           Dallas    TX  75201                 3         1
# 21           Dallas    TX  75219                 3         1
# 22           Dallas    TX  75219                 3         1
# 23           Dallas    TX  75206                 3         3
# 24           Dallas    TX  75210                 3         4
# 25           Dallas    TX  75210                 3         4
# 26           Dallas    TX  75225                 3         5
# 27           Dallas    TX  75238                 3         8
# 28           Dallas    TX  75240                 3         9
# 29         Mesquite    TX  75150                 3        10
# 30            Miami    FL  33137                 4         3
# 31            Miami    FL  33133                 4         4
# 32            Miami    FL  33142                 4         4
# 33     Key Biscayne    FL  33149                 4         4
# 34            Miami    FL  33138                 4         6
# 35      Miami Beach    FL  33141                 4         6
# 36            Miami    FL  33166                 4         9
# 37            Miami    FL  33166                 4         9
# 38            Miami    FL  33175                 4        14
# 39  Fort Lauderdale    FL  33312                 4        22
# 40        Nashville    TN  37208                 5         2
# 41        Nashville    TN  37208                 5         2
# 42        Nashville    TN  37212                 5         2
# 43        Nashville    TN  37212                 5         2
# 44        Nashville    TN  37204                 5         4
# 45        Nashville    TN  37207                 5         5
# 46        Nashville    TN  37215                 5         6
# 47          Madison    TN  37115                 5         8
# 48          Madison    TN  37115                 5         8
# 49        Brentwood    TN  37027                 5        11

# %%
rollback_before_flag = True
rollback_after_flag = True

query = """

select * 
from temp_sales;

"""

my_select_query_pandas(query, rollback_before_flag, rollback_after_flag)
# Out:
#     store_id  sale_id  customer_id   sale_date  total_amount
# 0          1   128112         3491  2020-04-30            24
# 1          1   144249         1597  2020-05-16            84
# 2          1   163141         4159  2020-06-04            96
# 3          1   169216         4198  2020-06-09           144
# 4          1   179181         5394  2020-06-18            48
# 5          1   181897         1958  2020-06-20            48
# 6          1   248269         4260  2020-08-22            60
# 7          1   250031         6782  2020-08-23            24
# 8          1   255285          563  2020-08-29            36
# 9          1   263524         1991  2020-09-07            48
# 10         2   105004        12160  2020-04-23            36
# 11         2   109083        11291  2020-04-27           132
# 12         2   115446        11779  2020-05-03            12
# 13         2   115912         9298  2020-05-04            48
# 14         2   119996        14460  2020-05-08            36
# 15         2   144107         9046  2020-06-06            96
# 16         2   158290         9189  2020-06-20            84
# 17         2   203726        12493  2020-08-08           132
# 18         2   217889        10295  2020-08-23            24
# 19         2   218323         9528  2020-08-23            48
# 20         3    99402        17003  2020-05-01            36
# 21         3   131547        19494  2020-06-10            84
# 22         3   131827        15481  2020-06-11           108
# 23         3   134868        16476  2020-06-14            48
# 24         3   154102        17711  2020-07-10            24
# 25         3   164376        15799  2020-07-22           108
# 26         3   177427        16932  2020-08-06            24
# 27         3   183488        15710  2020-08-13            12
# 28         3   186881        19226  2020-08-16           144
# 29         3   209184        19954  2020-09-13            36
# 30         4    89887        23902  2020-04-30            48
# 31         4   111979        25267  2020-05-31           108
# 32         4   115633        25339  2020-06-05           120
# 33         4   137286        23017  2020-07-05            24
# 34         4   138546        23347  2020-07-08            96
# 35         4   143587        22673  2020-07-14            60
# 36         4   177033        24014  2020-08-25            48
# 37         4   177233        23319  2020-08-26            60
# 38         4   183530        26882  2020-09-02           144
# 39         4   192337        27380  2020-09-16            96
# 40         5    88989        27926  2020-05-25            24
# 41         5   104373        29285  2020-06-18            48
# 42         5   105691        29783  2020-06-20            24
# 43         5   107715        29922  2020-06-24            36
# 44         5   109305        28267  2020-06-27           120
# 45         5   126722        28750  2020-07-26            36
# 46         5   136553        30184  2020-08-09            36
# 47         5   136735        27728  2020-08-10            96
# 48         5   147541        27654  2020-08-27            96
# 49         5   157919        27997  2020-09-14            48

# %%
rollback_before_flag = True
rollback_after_flag = True

query = """

select * 
from temp_random_sales;

"""

my_select_query_pandas(query, rollback_before_flag, rollback_after_flag)
# Out:
#     store_id  sale_id
# 0          1   128112
# 1          1   144249
# 2          1   163141
# 3          1   169216
# 4          1   179181
# 5          1   181897
# 6          1   248269
# 7          1   250031
# 8          1   255285
# 9          1   263524
# 10         2   105004
# 11         2   109083
# 12         2   115446
# 13         2   115912
# 14         2   119996
# 15         2   144107
# 16         2   158290
# 17         2   203726
# 18         2   217889
# 19         2   218323
# 20         3    99402
# 21         3   131547
# 22         3   131827
# 23         3   134868
# 24         3   154102
# 25         3   164376
# 26         3   177427
# 27         3   183488
# 28         3   186881
# 29         3   209184
# 30         4    89887
# 31         4   111979
# 32         4   115633
# 33         4   137286
# 34         4   138546
# 35         4   143587
# 36         4   177033
# 37         4   177233
# 38         4   183530
# 39         4   192337
# 40         5    88989
# 41         5   104373
# 42         5   105691
# 43         5   107715
# 44         5   109305
# 45         5   126722
# 46         5   136553
# 47         5   136735
# 48         5   147541
# 49         5   157919

# %% [markdown]
# ## You try it -
# * load the file temp_holidays.csv into the table temp_holidays
# * temp_products.csv into table temp_products
# * temp_line_items into table temp_line_items
# * verify the loads with a query

# %%
connection.rollback()

query = """

copy temp_holidays
from '/user/labs/week_06/temp_holidays.csv' delimiter ',' NULL '' csv header;

copy temp_products
from '/user/labs/week_06/temp_products.csv' delimiter ',' NULL '' csv header;

copy temp_line_items
from '/user/labs/week_06/temp_line_items.csv' delimiter ',' NULL '' csv header;

"""

cursor.execute(query)

connection.commit()

# %%
rollback_before_flag = True
rollback_after_flag = True

query = """

select * 
from temp_holidays;

"""

my_select_query_pandas(query, rollback_before_flag, rollback_after_flag)
# Out:
#    holiday_date       description  closed_flag
# 0    2020-01-01    New Year's Day        False
# 1    2020-01-20           MLK Day        False
# 2    2020-02-17   President's Day        False
# 3    2020-04-12            Easter        False
# 4    2020-05-10      Mother's Day        False
# 5    2020-05-25      Memorial Day        False
# 6    2020-06-21      Father's Day        False
# 7    2020-07-04  Independence Day        False
# 8    2020-09-07         Labor Day        False
# 9    2020-11-11     Veterans Days        False
# 10   2020-11-26      Thanksgiving         True
# 11   2020-12-25         Christmas         True

# %%
rollback_before_flag = True
rollback_after_flag = True

query = """

select * 
from temp_products;

"""

my_select_query_pandas(query, rollback_before_flag, rollback_after_flag)
# Out:
#    product_id        description
# 0           1   Pistachio Salmon
# 1           2   Teriyaki Chicken
# 2           3       Spinach Orzo
# 3           4   Eggplant Lasagna
# 4           5      Chicken Salad
# 5           6      Curry Chicken
# 6           7    Tilapia Piccata
# 7           8  Brocolli Stir Fry

# %%
rollback_before_flag = True
rollback_after_flag = True

query = """

select * 
from temp_line_items;

"""

my_select_query_pandas(query, rollback_before_flag, rollback_after_flag)
# Out:
#      store_id  sale_id  line_item_id  product_id  quantity
# 0           1   128112             1           1         1
# 1           1   128112             2           8         1
# 2           1   144249             1           1         1
# 3           1   144249             2           2         1
# 4           1   144249             3           4         2
# ..        ...      ...           ...         ...       ...
# 171         5   147541             4           4         1
# 172         5   147541             5           7         1
# 173         5   157919             1           1         1
# 174         5   157919             2           4         2
# 175         5   157919             3           7         1
#
# [176 rows x 5 columns]

# %% [markdown]
# # Lab: Extracting CSV Files

# %%
connection.rollback()
    
query = """
    
copy (select * 
      from temp_random_sales
      order by store_id, sale_id)
to '/user/labs/week_06/temp_random_sales_2.csv' delimiter ',' NULL '' csv header;

copy (select * 
      from temp_stores 
      order by store_id)
to '/user/labs/week_06/temp_stores_2.csv' delimiter ',' NULL '' csv header;


"""

cursor.execute(query)
    
connection.commit()

# %%
my_read_csv_file("temp_random_sales_2.csv", limit=10)
# Out:
# ['store_id', 'sale_id']
# ['1', '128112']
# ['1', '144249']
# ['1', '163141']
# ['1', '169216']
# ['1', '179181']
# ['1', '181897']
# ['1', '248269']
# ['1', '250031']
# ['1', '255285']
#
# Printed  10 lines of  51 total lines.

# %%
my_read_csv_file("temp_stores_2.csv", limit=10)
# Out:
# ['store_id', 'street', 'city', 'state', 'zip', 'latitude', 'longitude']
# ['1', '3000 Telegraph Ave', 'Berkeley', 'CA', '94705', '37.8555', '-122.2604']
# ['2', '1001 Broadway', 'Seattle', 'WA', '98122', '47.6114', '-122.3214']
# ['3', '2510 McKinney Ave', 'Dallas', 'TX', '75201', '32.7958', '-96.8015']
# ['4', '299 SE 3rd Ave', 'Miami', 'FL', '33131', '25.7720', '-80.1891']
# ['5', '1202 Broadway', 'Nashville', 'TN', '37203', '36.1568', '-86.7881']
#
# Printed  6 lines of  6 total lines.

# %% [markdown]
# ## You try it -
# * extract the table temp_sales table to temp_sales_2.csv
# * table temp_line_items to temp_line_items_2.csv
# * table temp_customers to temp_customers_2.csv
# * table temp_products to temp_products_2.csv
# * table temp_holidays to temp_holidays_2.csv
# * verify by reading the csv files

# %%
connection.rollback()
    
query = """
    
copy (select * 
      from temp_sales
      order by store_id, sale_id)
to '/user/labs/week_06/temp_sales_2.csv' delimiter ',' NULL '' csv header;

copy (select * 
      from temp_line_items 
      order by store_id)
to '/user/labs/week_06/temp_line_items_2.csv' delimiter ',' NULL '' csv header;

copy (select * 
      from temp_customers 
      order by customer_id)
to '/user/labs/week_06/temp_customers_2.csv' delimiter ',' NULL '' csv header;

copy (select * 
      from temp_products 
      order by product_id)
to '/user/labs/week_06/temp_products_2.csv' delimiter ',' NULL '' csv header;

copy (select * 
      from temp_holidays 
      order by holiday_date)
to '/user/labs/week_06/temp_holidays_2.csv' delimiter ',' NULL '' csv header;
"""

cursor.execute(query)
    
connection.commit()

# %%
my_read_csv_file("temp_sales_2.csv", limit=10)
# Out:
# ['store_id', 'sale_id', 'customer_id', 'sale_date', 'total_amount']
# ['1', '128112', '3491', '2020-04-30', '24']
# ['1', '144249', '1597', '2020-05-16', '84']
# ['1', '163141', '4159', '2020-06-04', '96']
# ['1', '169216', '4198', '2020-06-09', '144']
# ['1', '179181', '5394', '2020-06-18', '48']
# ['1', '181897', '1958', '2020-06-20', '48']
# ['1', '248269', '4260', '2020-08-22', '60']
# ['1', '250031', '6782', '2020-08-23', '24']
# ['1', '255285', '563', '2020-08-29', '36']
#
# Printed  10 lines of  51 total lines.

# %%
my_read_csv_file("temp_line_items_2.csv", limit=10)
# Out:
# ['store_id', 'sale_id', 'line_item_id', 'product_id', 'quantity']
# ['1', '128112', '1', '1', '1']
# ['1', '128112', '2', '8', '1']
# ['1', '144249', '1', '1', '1']
# ['1', '144249', '2', '2', '1']
# ['1', '144249', '3', '4', '2']
# ['1', '144249', '4', '6', '1']
# ['1', '144249', '5', '8', '2']
# ['1', '163141', '1', '1', '3']
# ['1', '163141', '2', '3', '1']
#
# Printed  10 lines of  177 total lines.

# %%
my_read_csv_file("temp_customers_2.csv", limit=10)
# Out:
# ['customer_id', 'first_name', 'last_name', 'street', 'city', 'state', 'zip', 'closest_store_id', 'distance']
# ['563', 'Rose', 'Slimings', '38 Iowa Street', 'Berkeley', 'CA', '94704', '1', '1']
# ['1597', 'Norry', 'Macauley', '654 Sommers Plaza', 'Oakland', 'CA', '94612', '1', '3']
# ['1958', 'Theresina', 'Penswick', '5975 Twin Pines Hill', 'Berkeley', 'CA', '94707', '1', '3']
# ['1991', 'Kevon', 'Wickett', '472 Arizona Court', 'Berkeley', 'CA', '94707', '1', '3']
# ['3491', 'Siouxie', "M'Quharge", '747 Westridge Center', 'Alameda', 'CA', '94501', '1', '6']
# ['4159', 'Cheryl', 'Broe', '7 Ruskin Alley', 'El Sobrante', 'CA', '94803', '1', '7']
# ['4198', 'Andreana', 'Drew', '11039 Cordelia Alley', 'El Sobrante', 'CA', '94803', '1', '7']
# ['4260', 'Dom', 'Risbrough', '3 Northland Crossing', 'Richmond', 'CA', '94805', '1', '7']
# ['5394', 'Katharina', 'Bavester', '522 Cordelia Lane', 'San Francisco', 'CA', '94102', '1', '10']
#
# Printed  10 lines of  51 total lines.

# %%
my_read_csv_file("temp_products_2.csv", limit=10)
# Out:
# ['product_id', 'description']
# ['1', 'Pistachio Salmon']
# ['2', 'Teriyaki Chicken']
# ['3', 'Spinach Orzo']
# ['4', 'Eggplant Lasagna']
# ['5', 'Chicken Salad']
# ['6', 'Curry Chicken']
# ['7', 'Tilapia Piccata']
# ['8', 'Brocolli Stir Fry']
#
# Printed  9 lines of  9 total lines.

# %%
my_read_csv_file("temp_holidays_2.csv", limit=10)
# Out:
# ['holiday_date', 'description', 'closed_flag']
# ['2020-01-01', "New Year's Day", 'f']
# ['2020-01-20', 'MLK Day', 'f']
# ['2020-02-17', "President's Day", 'f']
# ['2020-04-12', 'Easter', 'f']
# ['2020-05-10', "Mother's Day", 'f']
# ['2020-05-25', 'Memorial Day', 'f']
# ['2020-06-21', "Father's Day", 'f']
# ['2020-07-04', 'Independence Day', 'f']
# ['2020-09-07', 'Labor Day', 'f']
#
# Printed  10 lines of  13 total lines.
